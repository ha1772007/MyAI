# %%
JSONDATA = """
{
    "Chat Models": {
        "qwen_space": {
            "provider_id": "qwen_space",
            "function": "qwen_space",
            "api_url": "NO API Key Required",
            "models": [
                "72B"
            ],
            "default_api": [
                "No API"
            ],
            "flash_tool": false
        },
        "groq": {
            "provider_id": "groq",
            "function": "openai_completions",
            "api_url": "https://console.groq.com/keys",
            "models": [
                "llama-3.1-8b-instant",
                "llama-3.1-70b-versatile",
                "llama3-groq-70b-8192-tool-use-preview",
                "llama3-groq-8b-8192-tool-use-preview",
                "llama-3.1-405b-reasoning",
                "llama3-70b-8192",
                "llama3-8b-8192",
                "mixtral-8x7b-32768",
                "gemma-7b-it",
                "gemma2-9b-it"
            ],
            "functions_settings": {
                "endpoint": "https://api.groq.com/openai/v1/chat/completions",
                "tools": true
            },
            "default_api": [],
            "flash_tool": false
        },
        "hyperbolic": {
            "provider_id": "hyperbolic",
            "function": "openai_completions",
            "api_url": "https://app.hyperbolic.xyz/settings",
            "models": [
                "meta-llama/Llama-3.2-90B-Vision-Instruct",
                "meta-llama/Meta-Llama-3.1-405B-Instruct",
                "NousResearch/Hermes-3-Llama-3.1-70B",
                "Qwen/Qwen2.5-72B-Instruct",
                "meta-llama/Llama-3.2-3B-Instruct",
                "meta-llama/Meta-Llama-3.1-70B-Instruct",
                "meta-llama/Meta-Llama-3.1-8B-Instruct",
                "meta-llama/Llama-3.2-90B-Vision",
                "meta-llama/Meta-Llama-3.1-405B-FP8",
                "Qwen/Qwen2-VL-72B-Instruct",
                "meta-llama/Meta-Llama-3.1-405B",
                "Qwen/Qwen2-VL-7B-Instruct",
                "meta-llama/Meta-Llama-3-70B-Instruct",
                "deepseek-ai/DeepSeek-V2.5"
            ],
            "functions_settings": {
                "endpoint": "https://api.hyperbolic.xyz/v1/chat/completions",
                "tools": true
            },
            "default_api": [],
            "flash_tool": false
        },
        "mistral": {
            "provider_id": "mistral",
            "function": "openai_completions",
            "api_url": "https://console.mistral.ai/api-keys/",
            "models": [
                "open-mistral-7b",
                "open-mixtral-8x7b",
                "open-mixtral-8x22b",
                "mistral-small-2402",
                "mistral-small-2409",
                "mistral-medium",
                "mistral-large-2402",
                "mistral-large-2407",
                "codestral-2405",
                "codestral-mamba-2407",
                "open-mistral-nemo",
                "pixtral-12b-2409"
            ],
            "functions_settings": {
                "endpoint": "https://api.mistral.ai/v1/chat/completions",
                "tools": true
            },
            "default_api": [],
            "flash_tool": false
        },
        "together": {
            "provider_id": "together",
            "function": "openai_completions",
            "api_url": "https://api.together.ai/settings/api-keys",
            "models": [
                "codellama/CodeLlama-34b-Instruct-hf",
                "upstage/SOLAR-10.7B-Instruct-v1.0",
                "mistralai/Mixtral-8x7B-v0.1",
                "meta-llama/Meta-Llama-Guard-3-8B",
                "NousResearch/Nous-Hermes-2-Yi-34B",
                "togethercomputer/Llama-3-8b-chat-hf-int4",
                "google/gemma-2b-it",
                "Gryphe/MythoMax-L2-13b",
                "meta-llama/LlamaGuard-2-8b",
                "mistralai/Mistral-7B-Instruct-v0.1",
                "mistralai/Mistral-7B-Instruct-v0.2",
                "meta-llama/Meta-Llama-3-8B",
                "mistralai/Mistral-7B-v0.1",
                "Qwen/Qwen1.5-72B-Chat",
                "deepseek-ai/deepseek-llm-67b-chat",
                "Qwen/Qwen2-72B-Instruct",
                "togethercomputer/Llama-3-8b-chat-hf-int8",
                "mistralai/Mistral-7B-Instruct-v0.3",
                "meta-llama/Llama-2-13b-chat-hf",
                "meta-llama/Meta-Llama-3-70B-Instruct-Turbo",
                "meta-llama/Meta-Llama-3-70B-Instruct-Lite",
                "meta-llama/Meta-Llama-3.1-405B-Instruct-Turbo",
                "google/gemma-2-9b",
                "google/gemma-2-9b-it",
                "google/gemma-2-27b-it",
                "meta-llama/Llama-3-8b-chat-hf",
                "meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo",
                "meta-llama/Meta-Llama-3.1-70B-Instruct-Turbo",
                "mistralai/Mixtral-8x22B-Instruct-v0.1",
                "mistralai/Mixtral-8x7B-Instruct-v0.1",
                "microsoft/WizardLM-2-8x22B",
                "meta-llama/Meta-Llama-3.1-405B-Instruct-Lite-Pro",
                "test/meta-llama-3-2-11b-instruct-turbo",
                "meta-llama/Llama-3-70b-chat-hf",
                "Salesforce/Llama-Rank-V1",
                "llava-hf/llava-v1.6-mistral-7b-hf",
                "databricks/dbrx-instruct",
                "NousResearch/Nous-Hermes-2-Mixtral-8x7B-DPO",
                "meta-llama/Meta-Llama-3-8B-Instruct-Turbo",
                "meta-llama/Llama-2-70b-hf",
                "meta-llama/Meta-Llama-3-8B-Instruct-Lite",
                "Meta-Llama/Llama-Guard-7b",
                "Gryphe/MythoMax-L2-13b-Lite",
                "Qwen/Qwen1.5-110B-Chat",
                "meta-llama/Llama-2-7b-chat-hf",
                "meta-llama/Llama-3.1-405B-128K",
                "meta-llama/Llama-Vision-Free",
                "meta-llama/Llama-3.2-11B-Vision-Instruct-Turbo",
                "meta-llama/Llama-3.2-3B-Instruct-Turbo",
                "meta-llama/Llama-Guard-3-11B-Vision-Turbo",
                "meta-llama/Llama-3.2-90B-Vision-Instruct-Turbo",
                "test/meta-llama-3-2-3b-instruct-turbo",
                "hippocraticai/Meta-Llama-3.1-405B-Instruct-Turbo",
                "Nexusflow/NexusRaven-V2-13B",
                "bert-base-uncased",
                "WizardLM/WizardLM-13B-V1.2",
                "google/gemma-7b",
                "togethercomputer/Koala-7B",
                "zero-one-ai/Yi-34B",
                "Qwen/Qwen2-1.5B-Instruct",
                "togethercomputer/StripedHyena-Hessian-7B",
                "teknium/OpenHermes-2-Mistral-7B",
                "Qwen/Qwen2-7B-Instruct",
                "NousResearch/Nous-Hermes-13b",
                "togethercomputer/guanaco-65b",
                "togethercomputer/llama-2-7b",
                "huggyllama/llama-7b",
                "Undi95/ReMM-SLERP-L2-13B",
                "lmsys/vicuna-7b-v1.3",
                "Undi95/Toppy-M-7B",
                "Qwen/Qwen2-72B",
                "Phind/Phind-CodeLlama-34B-v2",
                "Phind/Phind-CodeLlama-34B-Python-v1",
                "NumbersStation/nsql-llama-2-7B",
                "NousResearch/Nous-Hermes-Llama2-70b",
                "WizardLM/WizardLM-70B-V1.0",
                "huggyllama/llama-65b",
                "lmsys/vicuna-13b-v1.5-16k",
                "openchat/openchat-3.5-1210",
                "HuggingFaceH4/zephyr-7b-beta",
                "Austism/chronos-hermes-13b",
                "Qwen/Qwen1.5-0.5B",
                "Qwen/Qwen1.5-1.8B",
                "Qwen/Qwen1.5-4B",
                "Qwen/Qwen1.5-7B",
                "snorkelai/Snorkel-Mistral-PairRM-DPO",
                "Qwen/Qwen1.5-14B-Chat",
                "Qwen/Qwen1.5-72B",
                "Qwen/Qwen1.5-1.8B-Chat",
                "Snowflake/snowflake-arctic-instruct",
                "togethercomputer/llama-2-13b",
                "NousResearch/Nous-Hermes-2-Mixtral-8x7B-SFT",
                "deepseek-ai/deepseek-coder-33b-instruct",
                "togethercomputer/CodeLlama-7b-Instruct",
                "codellama/CodeLlama-34b-Python-hf",
                "NousResearch/Nous-Hermes-Llama2-13b",
                "lmsys/vicuna-13b-v1.5",
                "togethercomputer/guanaco-13b",
                "codellama/CodeLlama-70b-Python-hf",
                "togethercomputer/CodeLlama-34b-Python",
                "togethercomputer/CodeLlama-34b-Instruct",
                "togethercomputer/CodeLlama-34b",
                "togethercomputer/llama-2-70b",
                "codellama/CodeLlama-13b-hf",
                "codellama/CodeLlama-13b-Instruct-hf",
                "Qwen/Qwen2-7B",
                "Qwen/Qwen2-1.5B",
                "togethercomputer/CodeLlama-13b-Instruct",
                "meta-llama/Llama-2-13b-hf",
                "togethercomputer/llama-2-13b-chat",
                "lmsys/vicuna-13b-v1.3",
                "huggyllama/llama-13b",
                "WizardLM/WizardCoder-Python-34B-V1.0",
                "huggyllama/llama-30b",
                "NousResearch/Nous-Hermes-2-Mistral-7B-DPO",
                "togethercomputer/alpaca-7b",
                "garage-bAInd/Platypus2-70B-instruct",
                "google/gemma-7b-it",
                "allenai/OLMo-7B",
                "allenai/OLMo-7B-Instruct",
                "togethercomputer/guanaco-33b",
                "togethercomputer/Koala-13B",
                "togethercomputer/llama-2-7b-chat",
                "togethercomputer/SOLAR-10.7B-Instruct-v1.0-int4",
                "togethercomputer/guanaco-7b",
                "Open-Orca/Mistral-7B-OpenOrca",
                "Qwen/Qwen1.5-32B",
                "EleutherAI/llemma_7b",
                "NousResearch/Nous-Hermes-llama-2-7b",
                "Qwen/Qwen1.5-32B-Chat",
                "NousResearch/Nous-Capybara-7B-V1p9",
                "meta-llama/Meta-Llama-3-70B",
                "meta-llama/Llama-3-8b-hf",
                "zero-one-ai/Yi-6B",
                "meta-llama/Meta-Llama-3-8B-Instruct",
                "lmsys/vicuna-7b-v1.5",
                "codellama/CodeLlama-34b-hf",
                "prompthero/openjourney",
                "meta-llama/Llama-2-7b-hf",
                "SG161222/Realistic_Vision_V3.0_VAE",
                "zero-one-ai/Yi-34B-Chat",
                "meta-llama/Meta-Llama-3-70B-Instruct",
                "meta-llama/Llama-3-70b-hf",
                "togethercomputer/CodeLlama-7b-Python",
                "codellama/CodeLlama-70b-hf",
                "togethercomputer/LLaMA-2-7B-32K",
                "codellama/CodeLlama-70b-Instruct-hf",
                "NousResearch/Hermes-2-Theta-Llama-3-70B",
                "test/test11",
                "microsoft/phi-2",
                "Qwen/Qwen1.5-7B-Chat",
                "cognitivecomputations/dolphin-2.5-mixtral-8x7b",
                "togethercomputer/evo-1-131k-base",
                "togethercomputer/evo-1-8k-base",
                "togethercomputer/CodeLlama-13b-Python",
                "codellama/CodeLlama-7b-hf",
                "togethercomputer/llama-2-70b-chat",
                "Qwen/Qwen1.5-14B",
                "codellama/CodeLlama-13b-Python-hf",
                "Qwen/Qwen1.5-0.5B-Chat",
                "codellama/CodeLlama-7b-Instruct-hf",
                "teknium/OpenHermes-2p5-Mistral-7B",
                "google/gemma-2b",
                "Qwen/Qwen1.5-4B-Chat",
                "mistralai/Mixtral-8x22B",
                "meta-llama/Llama-2-70b-chat-hf",
                "codellama/CodeLlama-7b-Python-hf",
                "carson/ml318br",
                "meta-llama/Meta-Llama-3.1-8B-Instruct-Reference",
                "meta-llama/Meta-Llama-3.1-8B-Reference",
                "albert/meta-llama-3-1-70b-instruct-turbo",
                "gradientai/Llama-3-70B-Instruct-Gradient-1048k",
                "meta-llama/Meta-Llama-3.1-70B-Instruct-Reference",
                "meta-llama/Meta-Llama-3.1-70B-Reference"
            ],
            "functions_settings": {
                "endpoint": "https://api.together.xyz/v1/chat/completions",
                "tools": true
            },
            "default_api": [],
            "flash_tool": false
        },
        "github": {
            "provider_id": "github",
            "function": "openai_completions",
            "api_url": "https://github.com/settings/tokens",
            "models": [
                "AI21-Jamba-Instruct",
                "Cohere-command-r",
                "Cohere-command-r-plus",
                "Meta-Llama-3-70B-Instruct",
                "Meta-Llama-3-8B-Instruct",
                "Meta-Llama-3.1-405B-Instruct",
                "Meta-Llama-3.1-70B-Instruct",
                "Meta-Llama-3.1-8B-Instruct",
                "Mistral-large",
                "Mistral-large-2407",
                "Mistral-Nemo",
                "Mistral-small",
                "gpt-4o",
                "gpt-4o-mini",
                "Phi-3-medium-128k-instruct",
                "Phi-3-medium-4k-instruct",
                "Phi-3-mini-128k-instruct",
                "Phi-3-mini-4k-instruct",
                "Phi-3-small-128k-instruct",
                "Phi-3-small-8k-instruct",
                "Phi-3.5-mini-instruct"
            ],
            "functions_settings": {
                "endpoint": "https://models.inference.ai.azure.com/chat/completions",
                "tools": true
            },
            "default_api": [],
            "flash_tool": false
        },
        "ai21": {
            "provider_id": "ai21",
            "function": "openai_completions",
            "api_url": "",
            "models": [
                "jamba-1.5-large"
            ],
            "functions_settings": {
                "endpoint": "https://api.ai21.com/studio/v1/chat/completions",
                "tools": true
            },
            "default_api": [],
            "flash_tool": false
        },
        "lepton": {
            "provider_id": "lepton",
            "function": "langchain_connect",
            "api_url": "https://dashboard.lepton.ai/",
            "models": [
                "llama3-1-405b",
                "llama3-1-70b",
                "llama3-1-8b",
                "nous-hermes-llama2-13b",
                "openchat-3-5",
                "wizardlm-2-7b",
                "mistral-7b",
                "toppy-m-7b",
                "gemma-7b",
                "mixtral-8x7b",
                "llama2-13b"
            ],
            "default_api": [],
            "flash_tool": false
        },
        "gemini": {
            "provider_id": "gemini",
            "function": "langchain_connect",
            "api_url": "https://aistudio.google.com/app/apikey",
            "models": [
                "gemini-1.5-flash-002",
                "gemini-1.5-flash-8b-exp-0924",
                "gemini-1.5-flash-8b-exp-0827",
                "gemini-1.5-flash-exp-0827",
                "gemini-1.5-flash",
                "gemini-1.5-flash-001-tuning",
                "gemini-1.5-flash-001",
                "gemini-1.5-flash-latest",
                "gemini-1.5-pro-exp-0827",
                "gemini-1.5-pro-exp-0801",
                "gemini-1.5-pro",
                "gemini-1.5-pro-002",
                "gemini-1.5-pro-001",
                "gemini-1.5-pro-latest",
                "gemini-1.0-pro-001",
                "gemini-pro",
                "gemini-1.0-pro",
                "gemini-1.0-pro-latest",
                "embedding-gecko-001",
                "text-bison-001",
                "chat-bison-001"
            ],
            "default_api": [],
            "flash_tool": false
        },
        "cohere": {
            "provider_id": "cohere",
            "function": "langchain_connect",
            "api_url": "https://dashboard.cohere.com/api-keys",
            "models": [
                "command-r-plus",
                "command-r",
                "command",
                "command-nightly",
                "command-light",
                "command-light-nightly"
            ],
            "default_api": [],
            "flash_tool": false
        },
        "openrouter": {
            "provider_id": "openrouter",
            "function": "openai_completions",
            "api_url": "https://openrouter.ai/settings/keys",
            "models": [
                "meta-llama/llama-3.2-11b-vision-instruct:free",
                "google/gemini-flash-8b-1.5-exp",
                "google/gemini-flash-1.5-exp",
                "nousresearch/hermes-3-llama-3.1-405b:free",
                "google/gemini-pro-1.5-exp",
                "meta-llama/llama-3.1-8b-instruct:free",
                "qwen/qwen-2-7b-instruct:free",
                "google/gemma-2-9b-it:free",
                "mistralai/mistral-7b-instruct:free",
                "microsoft/phi-3-mini-128k-instruct:free",
                "microsoft/phi-3-medium-128k-instruct:free",
                "meta-llama/llama-3-8b-instruct:free",
                "gryphe/mythomist-7b:free",
                "openchat/openchat-7b:free",
                "undi95/toppy-m-7b:free",
                "huggingfaceh4/zephyr-7b-beta:free"
            ],
            "default_api": [],
            "flash_tool": false,
            "functions_settings": {
                "endpoint": "https://openrouter.ai/api/v1/chat/completions",
                "tools": false
            }
        },
        "cloudflare": {
            "provider_id": "cloudflare",
            "function": "langchain_connect",
            "api_url": "https://dash.cloudflare.com/YOUR_ACCOUNT_ID/ai/workers-ai/api-quick-start",
            "models": [
                "@cf/unum/uform-gen2-qwen-500m",
                "@cf/facebook/detr-resnet-50",
                "@cf/facebook/bart-large-cnn",
                "@hf/thebloke/deepseek-coder-6.7b-base-awq",
                "@hf/thebloke/deepseek-coder-6.7b-instruct-awq",
                "@cf/deepseek-ai/deepseek-math-7b-base",
                "@cf/deepseek-ai/deepseek-math-7b-instruct",
                "@cf/thebloke/discolm-german-7b-v1-awq",
                "@cf/tiiuae/falcon-7b-instruct",
                "@cf/google/gemma-2b-it-lora",
                "@hf/google/gemma-7b-it",
                "@cf/google/gemma-7b-it-lora",
                "@hf/nousresearch/hermes-2-pro-mistral-7b",
                "@hf/thebloke/llama-2-13b-chat-awq",
                "@cf/meta-llama/llama-2-7b-chat-hf-lora",
                "@cf/meta/llama-3-8b-instruct",
                "@cf/meta/llama-3-8b-instruct-awq",
                "@cf/meta/llama-3.1-8b-instruct",
                "@hf/thebloke/llamaguard-7b-awq",
                "@hf/thebloke/mistral-7b-instruct-v0.1-awq",
                "@hf/mistral/mistral-7b-instruct-v0.2",
                "@cf/mistral/mistral-7b-instruct-v0.2-lora",
                "@hf/thebloke/neural-chat-7b-v3-1-awq",
                "@cf/openchat/openchat-3.5-0106",
                "@hf/thebloke/openhermes-2.5-mistral-7b-awq",
                "@cf/microsoft/phi-2",
                "@cf/qwen/qwen1.5-0.5b-chat",
                "@cf/qwen/qwen1.5-1.8b-chat",
                "@cf/qwen/qwen1.5-14b-chat-awq",
                "@cf/qwen/qwen1.5-7b-chat-awq",
                "@cf/defog/sqlcoder-7b-2",
                "@hf/nexusflow/starling-lm-7b-beta",
                "@cf/tinyllama/tinyllama-1.1b-chat-v1.0",
                "@cf/fblgit/una-cybertron-7b-v2-bf16",
                "@hf/thebloke/zephyr-7b-beta-awq"
            ],
            "default_api": [],
            "flash_tool": false
        },
        "segmind": {
            "provider_id": "segmind",
            "function": "langchain_connect",
            "api_url": "https://cloud.segmind.com/console/api-keys",
            "models": [
                "gpt-4o"
            ],
            "default_api": [],
            "flash_tool": false
        }
    }
}
"""

# %%
import json
data = json.loads(JSONDATA)
d = data['Chat Models']

# %%
from IPython.display import clear_output
final_output = {"Chat Model":{}}
test = {}
for key,value in d.items():
  # print(value)
  value['meta'] = {}
  for z in value['models']:
    print(key)
    print(z)
    repo = input("Enter Repo Address ")
    try:
      img = test[repo.split("/")[0]]
    except:
      img = input("Enter Image Link Here ")
    test[repo.split("/")[0]] = img
    value['meta'][z] = {
        "repo":repo,
        "img":img
    }
    final_output["Chat Model"][key] = value
    clear_output(wait=True)
# Out:
# together
# Qwen/Qwen2-7B-Instruct
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#      12   img = test[repo.split("/")[0]]
#      13 except:
# ---> 14   img = input("Enter Image Link Here ")
#      15 test[repo.split("/")[0]] = img
#      16 value['meta'][z] = {
#      17     "repo":repo,
#      18     "img":img
#      19 }
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import json
print(json.dumps(final_output,indent=4))
# Out:
# {
#     "Chat Model": {
#         "qwen_space": {
#             "provider_id": "qwen_space",
#             "function": "qwen_space",
#             "api_url": "NO API Key Required",
#             "models": [
#                 "72B"
#             ],
#             "default_api": [
#                 "No API"
#             ],
#             "flash_tool": false,
#             "meta": {
#                 "72B": {
#                     "repo": "Qwen/Qwen2-72B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62088594a5943c8a8fc94560/y5SEKiE8TkjBKs9xfjCx5.png"
#                 }
#             }
#         },
#         "groq": {
#             "provider_id": "groq",
#             "function": "openai_completions",
#             "api_url": "https://console.groq.com/keys",
#             "models": [
#                 "llama-3.1-8b-instant",
#                 "llama-3.1-70b-versatile",
#                 "llama3-groq-70b-8192-tool-use-preview",
#                 "llama3-groq-8b-8192-tool-use-preview",
#                 "llama-3.1-405b-reasoning",
#                 "llama3-70b-8192",
#                 "llama3-8b-8192",
#                 "mixtral-8x7b-32768",
#                 "gemma-7b-it",
#                 "gemma2-9b-it"
#             ],
#             "functions_settings": {
#                 "endpoint": "https://api.groq.com/openai/v1/chat/completions",
#                 "tools": true
#             },
#             "default_api": [],
#             "flash_tool": false,
#             "meta": {
#                 "llama-3.1-8b-instant": {
#                     "repo": "meta-llama/Llama-3.1-8B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "llama-3.1-70b-versatile": {
#                     "repo": "meta-llama/Llama-3.1-70B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "llama3-groq-70b-8192-tool-use-preview": {
#                     "repo": "Groq/Llama-3-Groq-8B-Tool-Use",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/1673913216963-63115d7864939fabc00f0b45.png"
#                 },
#                 "llama3-groq-8b-8192-tool-use-preview": {
#                     "repo": "Groq/Llama-3-Groq-8B-Tool-Use",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/1673913216963-63115d7864939fabc00f0b45.png"
#                 },
#                 "llama-3.1-405b-reasoning": {
#                     "repo": "meta-llama/Llama-3.1-405B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "llama3-70b-8192": {
#                     "repo": "meta-llama/Meta-Llama-3-70B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "llama3-8b-8192": {
#                     "repo": "meta-llama/Meta-Llama-3-8B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "mixtral-8x7b-32768": {
#                     "repo": "mistralai/Mixtral-8x7B-v0.1",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62dac1c7a8ead43d20e3e17a/wrLf5yaGC6ng4XME70w6Z.png"
#                 },
#                 "gemma-7b-it": {
#                     "repo": "mistralai/Mixtral-8x7B-v0.1",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62dac1c7a8ead43d20e3e17a/wrLf5yaGC6ng4XME70w6Z.png"
#                 },
#                 "gemma2-9b-it": {
#                     "repo": "google/gemma-2-9b-it",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/5dd96eb166059660ed1ee413/WtA3YYitedOr9n02eHfJe.png"
#                 }
#             }
#         },
#         "hyperbolic": {
#             "provider_id": "hyperbolic",
#             "function": "openai_completions",
#             "api_url": "https://app.hyperbolic.xyz/settings",
#             "models": [
#                 "meta-llama/Llama-3.2-90B-Vision-Instruct",
#                 "meta-llama/Meta-Llama-3.1-405B-Instruct",
#                 "NousResearch/Hermes-3-Llama-3.1-70B",
#                 "Qwen/Qwen2.5-72B-Instruct",
#                 "meta-llama/Llama-3.2-3B-Instruct",
#                 "meta-llama/Meta-Llama-3.1-70B-Instruct",
#                 "meta-llama/Meta-Llama-3.1-8B-Instruct",
#                 "meta-llama/Llama-3.2-90B-Vision",
#                 "meta-llama/Meta-Llama-3.1-405B-FP8",
#                 "Qwen/Qwen2-VL-72B-Instruct",
#                 "meta-llama/Meta-Llama-3.1-405B",
#                 "Qwen/Qwen2-VL-7B-Instruct",
#                 "meta-llama/Meta-Llama-3-70B-Instruct",
#                 "deepseek-ai/DeepSeek-V2.5"
#             ],
#             "functions_settings": {
#                 "endpoint": "https://api.hyperbolic.xyz/v1/chat/completions",
#                 "tools": true
#             },
#             "default_api": [],
#             "flash_tool": false,
#             "meta": {
#                 "meta-llama/Llama-3.2-90B-Vision-Instruct": {
#                     "repo": "meta-llama/Llama-3.2-90B-Vision-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Meta-Llama-3.1-405B-Instruct": {
#                     "repo": "meta-llama/Llama-3.2-90B-Vision-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "NousResearch/Hermes-3-Llama-3.1-70B": {
#                     "repo": "meta-llama/Meta-Llama-3.1-405B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "Qwen/Qwen2.5-72B-Instruct": {
#                     "repo": "Qwen/Qwen2.5-72B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62088594a5943c8a8fc94560/y5SEKiE8TkjBKs9xfjCx5.png"
#                 },
#                 "meta-llama/Llama-3.2-3B-Instruct": {
#                     "repo": "Qwen/Qwen2.5-72B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62088594a5943c8a8fc94560/y5SEKiE8TkjBKs9xfjCx5.png"
#                 },
#                 "meta-llama/Meta-Llama-3.1-70B-Instruct": {
#                     "repo": "meta-llama/Meta-Llama-3.1-70B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Meta-Llama-3.1-8B-Instruct": {
#                     "repo": "meta-llama/Meta-Llama-3.1-70B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Llama-3.2-90B-Vision": {
#                     "repo": "meta-llama/Llama-3.2-90B-Vision",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Meta-Llama-3.1-405B-FP8": {
#                     "repo": "meta-llama/Llama-3.2-90B-Vision",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "Qwen/Qwen2-VL-72B-Instruct": {
#                     "repo": "Qwen/Qwen2-VL-72B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62088594a5943c8a8fc94560/y5SEKiE8TkjBKs9xfjCx5.png"
#                 },
#                 "meta-llama/Meta-Llama-3.1-405B": {
#                     "repo": "meta-llama/Meta-Llama-3.1-405B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "Qwen/Qwen2-VL-7B-Instruct": {
#                     "repo": "Qwen/Qwen2-VL-7B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62088594a5943c8a8fc94560/y5SEKiE8TkjBKs9xfjCx5.png"
#                 },
#                 "meta-llama/Meta-Llama-3-70B-Instruct": {
#                     "repo": "Qwen/Qwen2-VL-7B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62088594a5943c8a8fc94560/y5SEKiE8TkjBKs9xfjCx5.png"
#                 },
#                 "deepseek-ai/DeepSeek-V2.5": {
#                     "repo": "deepseek-ai/DeepSeek-V2.5",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/6538815d1bdb3c40db94fbfa/xMBly9PUMphrFVMxLX4kq.png"
#                 }
#             }
#         },
#         "mistral": {
#             "provider_id": "mistral",
#             "function": "openai_completions",
#             "api_url": "https://console.mistral.ai/api-keys/",
#             "models": [
#                 "open-mistral-7b",
#                 "open-mixtral-8x7b",
#                 "open-mixtral-8x22b",
#                 "mistral-small-2402",
#                 "mistral-small-2409",
#                 "mistral-medium",
#                 "mistral-large-2402",
#                 "mistral-large-2407",
#                 "codestral-2405",
#                 "codestral-mamba-2407",
#                 "open-mistral-nemo",
#                 "pixtral-12b-2409"
#             ],
#             "functions_settings": {
#                 "endpoint": "https://api.mistral.ai/v1/chat/completions",
#                 "tools": true
#             },
#             "default_api": [],
#             "flash_tool": false,
#             "meta": {
#                 "open-mistral-7b": {
#                     "repo": "deepseek-ai/DeepSeek-V2.5",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/6538815d1bdb3c40db94fbfa/xMBly9PUMphrFVMxLX4kq.png"
#                 },
#                 "open-mixtral-8x7b": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "open-mixtral-8x22b": {
#                     "repo": "mistralai/Mixtral-8x22B-v0.1",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62dac1c7a8ead43d20e3e17a/wrLf5yaGC6ng4XME70w6Z.png"
#                 },
#                 "mistral-small-2402": {
#                     "repo": "mistralai/Mixtral-8x22B-v0.1",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62dac1c7a8ead43d20e3e17a/wrLf5yaGC6ng4XME70w6Z.png"
#                 },
#                 "mistral-small-2409": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "mistral-medium": {
#                     "repo": "mistralai/Mistral-7B-Instruct-v0.3",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62dac1c7a8ead43d20e3e17a/wrLf5yaGC6ng4XME70w6Z.png"
#                 },
#                 "mistral-large-2402": {
#                     "repo": "mistralai/Mistral-Large-Instruct-2407",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62dac1c7a8ead43d20e3e17a/wrLf5yaGC6ng4XME70w6Z.png"
#                 },
#                 "mistral-large-2407": {
#                     "repo": "mistralai/Mistral-Large-Instruct-2407",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62dac1c7a8ead43d20e3e17a/wrLf5yaGC6ng4XME70w6Z.png"
#                 },
#                 "codestral-2405": {
#                     "repo": "mistralai/Mistral-Large-Instruct-2407",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62dac1c7a8ead43d20e3e17a/wrLf5yaGC6ng4XME70w6Z.png"
#                 },
#                 "codestral-mamba-2407": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "open-mistral-nemo": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "pixtral-12b-2409": {
#                     "repo": "None/none",
#                     "img": "None"
#                 }
#             }
#         },
#         "together": {
#             "provider_id": "together",
#             "function": "openai_completions",
#             "api_url": "https://api.together.ai/settings/api-keys",
#             "models": [
#                 "codellama/CodeLlama-34b-Instruct-hf",
#                 "upstage/SOLAR-10.7B-Instruct-v1.0",
#                 "mistralai/Mixtral-8x7B-v0.1",
#                 "meta-llama/Meta-Llama-Guard-3-8B",
#                 "NousResearch/Nous-Hermes-2-Yi-34B",
#                 "togethercomputer/Llama-3-8b-chat-hf-int4",
#                 "google/gemma-2b-it",
#                 "Gryphe/MythoMax-L2-13b",
#                 "meta-llama/LlamaGuard-2-8b",
#                 "mistralai/Mistral-7B-Instruct-v0.1",
#                 "mistralai/Mistral-7B-Instruct-v0.2",
#                 "meta-llama/Meta-Llama-3-8B",
#                 "mistralai/Mistral-7B-v0.1",
#                 "Qwen/Qwen1.5-72B-Chat",
#                 "deepseek-ai/deepseek-llm-67b-chat",
#                 "Qwen/Qwen2-72B-Instruct",
#                 "togethercomputer/Llama-3-8b-chat-hf-int8",
#                 "mistralai/Mistral-7B-Instruct-v0.3",
#                 "meta-llama/Llama-2-13b-chat-hf",
#                 "meta-llama/Meta-Llama-3-70B-Instruct-Turbo",
#                 "meta-llama/Meta-Llama-3-70B-Instruct-Lite",
#                 "meta-llama/Meta-Llama-3.1-405B-Instruct-Turbo",
#                 "google/gemma-2-9b",
#                 "google/gemma-2-9b-it",
#                 "google/gemma-2-27b-it",
#                 "meta-llama/Llama-3-8b-chat-hf",
#                 "meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo",
#                 "meta-llama/Meta-Llama-3.1-70B-Instruct-Turbo",
#                 "mistralai/Mixtral-8x22B-Instruct-v0.1",
#                 "mistralai/Mixtral-8x7B-Instruct-v0.1",
#                 "microsoft/WizardLM-2-8x22B",
#                 "meta-llama/Meta-Llama-3.1-405B-Instruct-Lite-Pro",
#                 "test/meta-llama-3-2-11b-instruct-turbo",
#                 "meta-llama/Llama-3-70b-chat-hf",
#                 "Salesforce/Llama-Rank-V1",
#                 "llava-hf/llava-v1.6-mistral-7b-hf",
#                 "databricks/dbrx-instruct",
#                 "NousResearch/Nous-Hermes-2-Mixtral-8x7B-DPO",
#                 "meta-llama/Meta-Llama-3-8B-Instruct-Turbo",
#                 "meta-llama/Llama-2-70b-hf",
#                 "meta-llama/Meta-Llama-3-8B-Instruct-Lite",
#                 "Meta-Llama/Llama-Guard-7b",
#                 "Gryphe/MythoMax-L2-13b-Lite",
#                 "Qwen/Qwen1.5-110B-Chat",
#                 "meta-llama/Llama-2-7b-chat-hf",
#                 "meta-llama/Llama-3.1-405B-128K",
#                 "meta-llama/Llama-Vision-Free",
#                 "meta-llama/Llama-3.2-11B-Vision-Instruct-Turbo",
#                 "meta-llama/Llama-3.2-3B-Instruct-Turbo",
#                 "meta-llama/Llama-Guard-3-11B-Vision-Turbo",
#                 "meta-llama/Llama-3.2-90B-Vision-Instruct-Turbo",
#                 "test/meta-llama-3-2-3b-instruct-turbo",
#                 "hippocraticai/Meta-Llama-3.1-405B-Instruct-Turbo",
#                 "Nexusflow/NexusRaven-V2-13B",
#                 "bert-base-uncased",
#                 "WizardLM/WizardLM-13B-V1.2",
#                 "google/gemma-7b",
#                 "togethercomputer/Koala-7B",
#                 "zero-one-ai/Yi-34B",
#                 "Qwen/Qwen2-1.5B-Instruct",
#                 "togethercomputer/StripedHyena-Hessian-7B",
#                 "teknium/OpenHermes-2-Mistral-7B",
#                 "Qwen/Qwen2-7B-Instruct",
#                 "NousResearch/Nous-Hermes-13b",
#                 "togethercomputer/guanaco-65b",
#                 "togethercomputer/llama-2-7b",
#                 "huggyllama/llama-7b",
#                 "Undi95/ReMM-SLERP-L2-13B",
#                 "lmsys/vicuna-7b-v1.3",
#                 "Undi95/Toppy-M-7B",
#                 "Qwen/Qwen2-72B",
#                 "Phind/Phind-CodeLlama-34B-v2",
#                 "Phind/Phind-CodeLlama-34B-Python-v1",
#                 "NumbersStation/nsql-llama-2-7B",
#                 "NousResearch/Nous-Hermes-Llama2-70b",
#                 "WizardLM/WizardLM-70B-V1.0",
#                 "huggyllama/llama-65b",
#                 "lmsys/vicuna-13b-v1.5-16k",
#                 "openchat/openchat-3.5-1210",
#                 "HuggingFaceH4/zephyr-7b-beta",
#                 "Austism/chronos-hermes-13b",
#                 "Qwen/Qwen1.5-0.5B",
#                 "Qwen/Qwen1.5-1.8B",
#                 "Qwen/Qwen1.5-4B",
#                 "Qwen/Qwen1.5-7B",
#                 "snorkelai/Snorkel-Mistral-PairRM-DPO",
#                 "Qwen/Qwen1.5-14B-Chat",
#                 "Qwen/Qwen1.5-72B",
#                 "Qwen/Qwen1.5-1.8B-Chat",
#                 "Snowflake/snowflake-arctic-instruct",
#                 "togethercomputer/llama-2-13b",
#                 "NousResearch/Nous-Hermes-2-Mixtral-8x7B-SFT",
#                 "deepseek-ai/deepseek-coder-33b-instruct",
#                 "togethercomputer/CodeLlama-7b-Instruct",
#                 "codellama/CodeLlama-34b-Python-hf",
#                 "NousResearch/Nous-Hermes-Llama2-13b",
#                 "lmsys/vicuna-13b-v1.5",
#                 "togethercomputer/guanaco-13b",
#                 "codellama/CodeLlama-70b-Python-hf",
#                 "togethercomputer/CodeLlama-34b-Python",
#                 "togethercomputer/CodeLlama-34b-Instruct",
#                 "togethercomputer/CodeLlama-34b",
#                 "togethercomputer/llama-2-70b",
#                 "codellama/CodeLlama-13b-hf",
#                 "codellama/CodeLlama-13b-Instruct-hf",
#                 "Qwen/Qwen2-7B",
#                 "Qwen/Qwen2-1.5B",
#                 "togethercomputer/CodeLlama-13b-Instruct",
#                 "meta-llama/Llama-2-13b-hf",
#                 "togethercomputer/llama-2-13b-chat",
#                 "lmsys/vicuna-13b-v1.3",
#                 "huggyllama/llama-13b",
#                 "WizardLM/WizardCoder-Python-34B-V1.0",
#                 "huggyllama/llama-30b",
#                 "NousResearch/Nous-Hermes-2-Mistral-7B-DPO",
#                 "togethercomputer/alpaca-7b",
#                 "garage-bAInd/Platypus2-70B-instruct",
#                 "google/gemma-7b-it",
#                 "allenai/OLMo-7B",
#                 "allenai/OLMo-7B-Instruct",
#                 "togethercomputer/guanaco-33b",
#                 "togethercomputer/Koala-13B",
#                 "togethercomputer/llama-2-7b-chat",
#                 "togethercomputer/SOLAR-10.7B-Instruct-v1.0-int4",
#                 "togethercomputer/guanaco-7b",
#                 "Open-Orca/Mistral-7B-OpenOrca",
#                 "Qwen/Qwen1.5-32B",
#                 "EleutherAI/llemma_7b",
#                 "NousResearch/Nous-Hermes-llama-2-7b",
#                 "Qwen/Qwen1.5-32B-Chat",
#                 "NousResearch/Nous-Capybara-7B-V1p9",
#                 "meta-llama/Meta-Llama-3-70B",
#                 "meta-llama/Llama-3-8b-hf",
#                 "zero-one-ai/Yi-6B",
#                 "meta-llama/Meta-Llama-3-8B-Instruct",
#                 "lmsys/vicuna-7b-v1.5",
#                 "codellama/CodeLlama-34b-hf",
#                 "prompthero/openjourney",
#                 "meta-llama/Llama-2-7b-hf",
#                 "SG161222/Realistic_Vision_V3.0_VAE",
#                 "zero-one-ai/Yi-34B-Chat",
#                 "meta-llama/Meta-Llama-3-70B-Instruct",
#                 "meta-llama/Llama-3-70b-hf",
#                 "togethercomputer/CodeLlama-7b-Python",
#                 "codellama/CodeLlama-70b-hf",
#                 "togethercomputer/LLaMA-2-7B-32K",
#                 "codellama/CodeLlama-70b-Instruct-hf",
#                 "NousResearch/Hermes-2-Theta-Llama-3-70B",
#                 "test/test11",
#                 "microsoft/phi-2",
#                 "Qwen/Qwen1.5-7B-Chat",
#                 "cognitivecomputations/dolphin-2.5-mixtral-8x7b",
#                 "togethercomputer/evo-1-131k-base",
#                 "togethercomputer/evo-1-8k-base",
#                 "togethercomputer/CodeLlama-13b-Python",
#                 "codellama/CodeLlama-7b-hf",
#                 "togethercomputer/llama-2-70b-chat",
#                 "Qwen/Qwen1.5-14B",
#                 "codellama/CodeLlama-13b-Python-hf",
#                 "Qwen/Qwen1.5-0.5B-Chat",
#                 "codellama/CodeLlama-7b-Instruct-hf",
#                 "teknium/OpenHermes-2p5-Mistral-7B",
#                 "google/gemma-2b",
#                 "Qwen/Qwen1.5-4B-Chat",
#                 "mistralai/Mixtral-8x22B",
#                 "meta-llama/Llama-2-70b-chat-hf",
#                 "codellama/CodeLlama-7b-Python-hf",
#                 "carson/ml318br",
#                 "meta-llama/Meta-Llama-3.1-8B-Instruct-Reference",
#                 "meta-llama/Meta-Llama-3.1-8B-Reference",
#                 "albert/meta-llama-3-1-70b-instruct-turbo",
#                 "gradientai/Llama-3-70B-Instruct-Gradient-1048k",
#                 "meta-llama/Meta-Llama-3.1-70B-Instruct-Reference",
#                 "meta-llama/Meta-Llama-3.1-70B-Reference"
#             ],
#             "functions_settings": {
#                 "endpoint": "https://api.together.xyz/v1/chat/completions",
#                 "tools": true
#             },
#             "default_api": [],
#             "flash_tool": false,
#             "meta": {
#                 "codellama/CodeLlama-34b-Instruct-hf": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "upstage/SOLAR-10.7B-Instruct-v1.0": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "mistralai/Mixtral-8x7B-v0.1": {
#                     "repo": "mistralai/Mixtral-8x7B-v0.1",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62dac1c7a8ead43d20e3e17a/wrLf5yaGC6ng4XME70w6Z.png"
#                 },
#                 "meta-llama/Meta-Llama-Guard-3-8B": {
#                     "repo": "mistralai/Mixtral-8x7B-v0.1",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62dac1c7a8ead43d20e3e17a/wrLf5yaGC6ng4XME70w6Z.png"
#                 },
#                 "NousResearch/Nous-Hermes-2-Yi-34B": {
#                     "repo": "meta-llama/Meta-Llama-Guard-3-8B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "togethercomputer/Llama-3-8b-chat-hf-int4": {
#                     "repo": "NousResearch/Nous-Hermes-2-Yi-34B",
#                     "img": "togethercomputer/Llama-3-8b-chat-hf-int4"
#                 },
#                 "google/gemma-2b-it": {
#                     "repo": "google/gemma-2b-it",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/5dd96eb166059660ed1ee413/WtA3YYitedOr9n02eHfJe.png"
#                 },
#                 "Gryphe/MythoMax-L2-13b": {
#                     "repo": "Gryphe/MythoMax-L2-13b",
#                     "img": "Gryphe/MythoMax-L2-13b"
#                 },
#                 "meta-llama/LlamaGuard-2-8b": {
#                     "repo": "Gryphe/MythoMax-L2-13b",
#                     "img": "Gryphe/MythoMax-L2-13b"
#                 },
#                 "mistralai/Mistral-7B-Instruct-v0.1": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "mistralai/Mistral-7B-Instruct-v0.2": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "meta-llama/Meta-Llama-3-8B": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "mistralai/Mistral-7B-v0.1": {
#                     "repo": "mistralai/Mistral-7B-v0.1",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62dac1c7a8ead43d20e3e17a/wrLf5yaGC6ng4XME70w6Z.png"
#                 },
#                 "Qwen/Qwen1.5-72B-Chat": {
#                     "repo": "Qwen/Qwen1.5-72B-Chat",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62088594a5943c8a8fc94560/y5SEKiE8TkjBKs9xfjCx5.png"
#                 },
#                 "deepseek-ai/deepseek-llm-67b-chat": {
#                     "repo": "deepseek-ai/deepseek-llm-67b-chat",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/6538815d1bdb3c40db94fbfa/xMBly9PUMphrFVMxLX4kq.png"
#                 },
#                 "Qwen/Qwen2-72B-Instruct": {
#                     "repo": "Qwen/Qwen2-72B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62088594a5943c8a8fc94560/y5SEKiE8TkjBKs9xfjCx5.png"
#                 },
#                 "togethercomputer/Llama-3-8b-chat-hf-int8": {
#                     "repo": "togethercomputer/Llama-3-8b-chat-hf-int8",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "mistralai/Mistral-7B-Instruct-v0.3": {
#                     "repo": "meta-llama/Meta-Llama-3-8B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Llama-2-13b-chat-hf": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "meta-llama/Meta-Llama-3-70B-Instruct-Turbo": {
#                     "repo": "meta-llama/Meta-Llama-3-70B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Meta-Llama-3-70B-Instruct-Lite": {
#                     "repo": "meta-llama/Meta-Llama-3-70B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Meta-Llama-3.1-405B-Instruct-Turbo": {
#                     "repo": "meta-llama/Llama-3.1-405B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "google/gemma-2-9b": {
#                     "repo": "google/gemma-2-9b-it",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/5dd96eb166059660ed1ee413/WtA3YYitedOr9n02eHfJe.png"
#                 },
#                 "google/gemma-2-9b-it": {
#                     "repo": "google/gemma-2-9b-it",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/5dd96eb166059660ed1ee413/WtA3YYitedOr9n02eHfJe.png"
#                 },
#                 "google/gemma-2-27b-it": {
#                     "repo": "google/gemma-2-9b-it",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/5dd96eb166059660ed1ee413/WtA3YYitedOr9n02eHfJe.png"
#                 },
#                 "meta-llama/Llama-3-8b-chat-hf": {
#                     "repo": "google/gemma-2-27b-it",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/5dd96eb166059660ed1ee413/WtA3YYitedOr9n02eHfJe.png"
#                 },
#                 "meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "meta-llama/Meta-Llama-3.1-70B-Instruct-Turbo": {
#                     "repo": "meta-llama/Llama-3.1-70B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "mistralai/Mixtral-8x22B-Instruct-v0.1": {
#                     "repo": "mistral-community/Mixtral-8x22B-v0.1",
#                     "img": "mistralai/Mixtral-8x22B-Instruct-v0.1"
#                 },
#                 "mistralai/Mixtral-8x7B-Instruct-v0.1": {
#                     "repo": "mistralai/Mixtral-8x7B-Instruct-v0.1",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62dac1c7a8ead43d20e3e17a/wrLf5yaGC6ng4XME70w6Z.png"
#                 },
#                 "microsoft/WizardLM-2-8x22B": {
#                     "repo": "alpindale/WizardLM-2-8x22B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/635567189c72a7e742f1419c/tbfBz0furS-y4ISgoe6j0.jpeg"
#                 },
#                 "meta-llama/Meta-Llama-3.1-405B-Instruct-Lite-Pro": {
#                     "repo": "meta-llama/Llama-3.1-405B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "test/meta-llama-3-2-11b-instruct-turbo": {
#                     "repo": "meta-llama/Llama-3.2-11B-Vision",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Llama-3-70b-chat-hf": {
#                     "repo": "meta-llama/Meta-Llama-3-70B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "Salesforce/Llama-Rank-V1": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "llava-hf/llava-v1.6-mistral-7b-hf": {
#                     "repo": "llava-hf/llava-v1.6-mistral-7b-hf",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/5f1158120c833276f61f1a84/HYIF0By10WazlTdVv3xp0.jpeg"
#                 },
#                 "databricks/dbrx-instruct": {
#                     "repo": "databricks/dbrx-instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/1659441070587-62e90f4cf7e720c6b13648d8.png"
#                 },
#                 "NousResearch/Nous-Hermes-2-Mixtral-8x7B-DPO": {
#                     "repo": "NousResearch/Nous-Hermes-2-Mixtral-8x7B-DPO",
#                     "img": "togethercomputer/Llama-3-8b-chat-hf-int4"
#                 },
#                 "meta-llama/Meta-Llama-3-8B-Instruct-Turbo": {
#                     "repo": "https://cdn-avatars.huggingface.co/v1/production/uploads/6317aade83d8d2fd903192d9/tPLjYEeP6q1w0j_G2TJG_.png",
#                     "img": "meta-llama/Meta-Llama-3-8B-Instruct"
#                 },
#                 "meta-llama/Llama-2-70b-hf": {
#                     "repo": "meta-llama/Llama-2-70b-hf",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Meta-Llama-3-8B-Instruct-Lite": {
#                     "repo": "meta-llama/Meta-Llama-3-8B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "Meta-Llama/Llama-Guard-7b": {
#                     "repo": "meta-llama/LlamaGuard-7b",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "Gryphe/MythoMax-L2-13b-Lite": {
#                     "repo": "Gryphe/MythoMax-L2-13b",
#                     "img": "Gryphe/MythoMax-L2-13b"
#                 },
#                 "Qwen/Qwen1.5-110B-Chat": {
#                     "repo": "Qwen/Qwen1.5-110B-Chat",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62088594a5943c8a8fc94560/y5SEKiE8TkjBKs9xfjCx5.png"
#                 },
#                 "meta-llama/Llama-2-7b-chat-hf": {
#                     "repo": "meta-llama/Llama-2-7b-chat-hf",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Llama-3.1-405B-128K": {
#                     "repo": "meta-llama/Llama-3.1-405B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Llama-Vision-Free": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "meta-llama/Llama-3.2-11B-Vision-Instruct-Turbo": {
#                     "repo": "meta-llama/Llama-3.2-11B-Vision-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Llama-3.2-3B-Instruct-Turbo": {
#                     "repo": "meta-llama/Llama-3.2-3B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Llama-Guard-3-11B-Vision-Turbo": {
#                     "repo": "meta-llama/Llama-Guard-3-11B-Vision",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "meta-llama/Llama-3.2-90B-Vision-Instruct-Turbo": {
#                     "repo": "meta-llama/Llama-3.2-90B-Vision-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "test/meta-llama-3-2-3b-instruct-turbo": {
#                     "repo": "meta-llama/Llama-3.2-3B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "hippocraticai/Meta-Llama-3.1-405B-Instruct-Turbo": {
#                     "repo": "meta-llama/Llama-3.2-3B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "Nexusflow/NexusRaven-V2-13B": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "bert-base-uncased": {
#                     "repo": "google-bert/bert-base-uncased",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/5dd96eb166059660ed1ee413/TmmBAiyUIfm_mM3OtySkw.png"
#                 },
#                 "WizardLM/WizardLM-13B-V1.2": {
#                     "repo": "WizardLM/WizardLM-13B-V1.2",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/627b9f3f4d0858f0034efbb9/KxPkS7r7aWmMKFdyLOoSg.png"
#                 },
#                 "google/gemma-7b": {
#                     "repo": "google/gemma-7b",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/5dd96eb166059660ed1ee413/WtA3YYitedOr9n02eHfJe.png"
#                 },
#                 "togethercomputer/Koala-7B": {
#                     "repo": "None/None",
#                     "img": "None"
#                 },
#                 "zero-one-ai/Yi-34B": {
#                     "repo": "01-ai/Yi-1.5-34B-Chat",
#                     "img": "https://raw.githubusercontent.com/01-ai/Yi/main/assets/img/Yi_logo_icon_light.svg"
#                 },
#                 "Qwen/Qwen2-1.5B-Instruct": {
#                     "repo": "Qwen/Qwen2-1.5B-Instruct",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/62088594a5943c8a8fc94560/y5SEKiE8TkjBKs9xfjCx5.png"
#                 },
#                 "togethercomputer/StripedHyena-Hessian-7B": {
#                     "repo": "togethercomputer/StripedHyena-Hessian-7B",
#                     "img": "https://cdn-avatars.huggingface.co/v1/production/uploads/646cf8084eefb026fb8fd8bc/oCTqufkdTkjyGodsx1vo1.png"
#                 },
#                 "teknium/OpenHermes-2-Mistral-7B": {
#                     "repo": "https://cdn-avatars.huggingface.co/v1/production/uploads/1678734258201-6322ad266b1992383fa964ca.png",
#                     "img": "meta-llama/Meta-Llama-3-8B-Instruct"
#                 }
#             }
#         }
#     }
# }
